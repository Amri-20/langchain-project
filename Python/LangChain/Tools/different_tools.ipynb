# %% [markdown]
# DcukDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

# %%
searchTool=DuckDuckGoSearchRun()

# %%
result = searchTool.invoke('top news in india')
print(result)
# Out:
# A ranked list of the top 10 cryptocurrency news media outlets in India, covering sources focused on blockchain, crypto markets, regulations, and related developments in the Indian context. The ranking is based on factors such as audience reach, cred… 13 hours ago - Nashik TCS row deepens: 4 accused held in fresh case; employee’s wife also 'targeted' ... From Clarke to Yuvraj: Cricketers who battled cancer with courage201 wickets, one favourite: Tendulkar's pick will surprise youAsia Cup 2025: Indian-origin ... 13 hours ago - India's 2026 wheat output was seen at 110.65 million metric tons, below the government record estimate of 120.21 million tons, the country's flour millers' body said on Friday. 5 hours ago - Hamas operatives, including Oct. 7 infiltrator, killed in Gaza strike: IDF · Deepti Sharma redeems herself, saves India from T20I series whitewash vs South Africa 19 hours ago - IPL 2026: KL Rahul creates IPL history with unique 3-franchise century feat · KL Rahul unleashed a sensational unbeaten 152, a record for an Indian in the IPL, as Delhi Capitals posted a colossal 264/2 against Punjab Kings.

# %%
print(searchTool.name)
print(searchTool.description)
print(searchTool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# Shell Tool

# %%
from langchain_community.tools import ShellTool

# %%
shell_tool=ShellTool()

# %%
result=shell_tool.invoke('ls')
print(result)
# Out:
# Executing command:
#  ls
# different_tools.ipynb
