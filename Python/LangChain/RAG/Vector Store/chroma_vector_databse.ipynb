# %%
# Out:
# Requirement already satisfied: langchain in c:\Coding\Python\.venv\Lib\site-packages (1.2.13)
# Collecting chromadb
#   Downloading chromadb-1.5.7-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: openai in c:\Coding\Python\.venv\Lib\site-packages (2.30.0)
# Requirement already satisfied: tiktoken in c:\Coding\Python\.venv\Lib\site-packages (0.12.0)
# Requirement already satisfied: pypdf in c:\Coding\Python\.venv\Lib\site-packages (6.9.2)
# Requirement already satisfied: langchain_openai in c:\Coding\Python\.venv\Lib\site-packages (1.1.12)
# Requirement already satisfied: langchain-community in c:\Coding\Python\.venv\Lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\Coding\Python\.venv\Lib\site-packages (from langchain) (1.2.23)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in c:\Coding\Python\.venv\Lib\site-packages (from langchain) (1.1.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Coding\Python\.venv\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Coding\Python\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Coding\Python\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Coding\Python\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Coding\Python\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Coding\Python\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\Coding\Python\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\Coding\Python\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\Coding\Python\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\Coding\Python\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Coding\Python\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Coding\Python\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Coding\Python\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Coding\Python\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.4.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (2.13.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp314-cp314-win_amd64.whl.metadata (9.1 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.44.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (2.4.4)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.24.4-cp314-cp314-win_amd64.whl.metadata (5.4 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.41.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.41.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (1.80.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (0.24.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp314-cp314-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Coding\Python\.venv\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Coding\Python\.venv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Coding\Python\.venv\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in c:\Coding\Python\.venv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\Coding\Python\.venv\Lib\site-packages (from tiktoken) (2026.3.32)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Coding\Python\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\Coding\Python\.venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\Coding\Python\.venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in c:\Coding\Python\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Coding\Python\.venv\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Coding\Python\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Coding\Python\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\Coding\Python\.venv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\Coding\Python\.venv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\Coding\Python\.venv\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Coding\Python\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Coding\Python\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Coding\Python\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\Coding\Python\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Coding\Python\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf in c:\Coding\Python\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: sympy in c:\Coding\Python\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Downloading zipp-3.23.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Coding\Python\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.41.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.41.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.62b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.62b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Coding\Python\.venv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Coding\Python\.venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Coding\Python\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\Coding\Python\.venv\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\Coding\Python\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Coding\Python\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\Coding\Python\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.2)
# Requirement already satisfied: click>=8.2.1 in c:\Coding\Python\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Coding\Python\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Coding\Python\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp314-cp314-win_amd64.whl.metadata (3.6 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp314-cp314-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in c:\Coding\Python\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Coding\Python\.venv\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.5.7-cp39-abi3-win_amd64.whl (23.1 MB)
#    ---------------------------------------- 0.0/23.1 MB ? eta -:--:--
#    ------- -------------------------------- 4.5/23.1 MB 28.2 MB/s eta 0:00:01
#    -------------------------- ------------- 15.2/23.1 MB 40.8 MB/s eta 0:00:01
#    ---------------------------------------- 23.1/23.1 MB 42.5 MB/s  0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.4.3-py3-none-any.whl (26 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 81.0 MB/s  0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp314-cp314-win_amd64.whl (42 kB)
# Downloading onnxruntime-1.24.4-cp314-cp314-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 12.9/12.9 MB 66.5 MB/s  0:00:00
# Downloading opentelemetry_api-1.41.0-py3-none-any.whl (69 kB)
# Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.41.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.41.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.41.0-py3-none-any.whl (180 kB)
# Downloading opentelemetry_semantic_conventions-0.62b0-py3-none-any.whl (231 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp314-cp314-win_amd64.whl (36 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading uvicorn-0.44.0-py3-none-any.whl (69 kB)
# Downloading httptools-0.7.1-cp314-cp314-win_amd64.whl (88 kB)
# Downloading watchfiles-1.1.1-cp314-cp314-win_amd64.whl (287 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websocket-client, pyproject_hooks, pybase64, overrides, opentelemetry-proto, oauthlib, mmh3, importlib-resources, httptools, bcrypt, watchfiles, uvicorn, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, onnxruntime, importlib-metadata, build, opentelemetry-api, kubernetes, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/27 [pypika]
#    ----------------------------------------  0/27 [pypika]
#    - --------------------------------------  1/27 [flatbuffers]
#    ---- -----------------------------------  3/27 [zipp]
#    ----- ----------------------------------  4/27 [websocket-client]
#    ----- ----------------------------------  4/27 [websocket-client]
#    ----- ----------------------------------  4/27 [websocket-client]
#    ----- ----------------------------------  4/27 [websocket-client]
#    ------- --------------------------------  5/27 [pyproject_hooks]
#    -------- -------------------------------  6/27 [pybase64]
#    ---------- -----------------------------  7/27 [overrides]
#    ----------- ----------------------------  8/27 [opentelemetry-proto]
#    ----------- ----------------------------  8/27 [opentelemetry-proto]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ------------- --------------------------  9/27 [oauthlib]
#    ---------------- ----------------------- 11/27 [importlib-resources]
#    ---------------- ----------------------- 11/27 [importlib-resources]
#    ---------------- ----------------------- 11/27 [importlib-resources]
#    ----------------- ---------------------- 12/27 [httptools]
#    -------------------- ------------------- 14/27 [watchfiles]
#    -------------------- ------------------- 14/27 [watchfiles]
#    ---------------------- ----------------- 15/27 [uvicorn]
#    ---------------------- ----------------- 15/27 [uvicorn]
#    ---------------------- ----------------- 15/27 [uvicorn]
#    ---------------------- ----------------- 15/27 [uvicorn]
#    ---------------------- ----------------- 15/27 [uvicorn]
#    ----------------------- ---------------- 16/27 [requests-oauthlib]
#    ----------------- --------- 17/27 [opentelemetry-exporter-otlp-proto-common]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    -------------------------- ------------- 18/27 [onnxruntime]
#    ---------------------------- ----------- 19/27 [importlib-metadata]
#    ----------------------------- ---------- 20/27 [build]
#    ----------------------------- ---------- 20/27 [build]
#    ----------------------------- ---------- 20/27 [build]
#    ------------------------------- -------- 21/27 [opentelemetry-api]
#    ------------------------------- -------- 21/27 [opentelemetry-api]
#    ------------------------------- -------- 21/27 [opentelemetry-api]
#    ------------------------------- -------- 21/27 [opentelemetry-api]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    -------------------------------- ------- 22/27 [kubernetes]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 23/27 [opentelemetry-semantic-conventions]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [opentelemetry-sdk]
#    -------------------------- -- 25/27 [opentelemetry-exporter-otlp-proto-grpc]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    ---------------------------------------- 27/27 [chromadb]
#
# Successfully installed bcrypt-5.0.0 build-1.4.3 chromadb-1.5.7 durationpy-0.10 flatbuffers-25.12.19 httptools-0.7.1 importlib-metadata-8.7.1 importlib-resources-7.1.0 kubernetes-35.0.0 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.24.4 opentelemetry-api-1.41.0 opentelemetry-exporter-otlp-proto-common-1.41.0 opentelemetry-exporter-otlp-proto-grpc-1.41.0 opentelemetry-proto-1.41.0 opentelemetry-sdk-1.41.0 opentelemetry-semantic-conventions-0.62b0 overrides-7.7.0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 uvicorn-0.44.0 watchfiles-1.1.1 websocket-client-1.9.0 zipp-3.23.1

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document

# %%
doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs=[doc1, doc2, doc3, doc4, doc5]

# %%
vector_store=Chroma(
    embedding_function=HuggingFaceEmbeddings(
        model_name='sentence-transformers/all-MiniLM-L6-v2'
    ),
    persist_directory='my_chroma_db',
    collection_name='sample'
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 8980.82it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#this is the id of each document
vector_store.add_documents(docs)
# Out:
# ['9a55bd5b-a6f2-479d-a7ec-610f0017f0e9',
#  '61f56922-94ee-45c3-bbe9-ff23ac78ea4d',
#  'b5a97514-cfad-4c3d-943c-c5b5de646609',
#  '7021b11c-f14b-4021-885b-652242acfbc9',
#  'd790263b-ec9f-471d-928a-dfd18a0c491e']

# %%
# view documents
vector_store.get(
    include=['embeddings', 'documents', 'metadatas'],
    limit=5
)
#1st->embeddings:- embeddings of each document[vector of each doc]
# Out:
# {'ids': ['5b540f85-3e13-44a5-8c59-1c9fe45cfbcf',
#   '209547b5-3a65-4d7b-9754-f26ffee9907c',
#   '57921b8e-bbb6-4420-9780-d51299cc00e2',
#   'cac9f275-6dba-4c60-b5f1-ff687d6ce92b',
#   'f6fa0844-6543-4570-be54-39b091c72eff'],
#  'embeddings': array([[ 0.00994726,  0.06914339, -0.05147114, ..., -0.03543339,
#           0.0128481 ,  0.0124829 ],
#         [ 0.00127745,  0.0312985 , -0.02375377, ..., -0.00518358,
#          -0.03280613,  0.02737715],
#         [-0.10265917,  0.02650809,  0.02271502, ..., -0.03359748,
#          -0.07984944, -0.01507708],
#         [ 0.02123395, -0.02468547, -0.04494376, ..., -0.1099581 ,
#           0.0057256 ,  0.09915379],
#         [ 0.0187398 ,  0.04382846, -0.04304254, ..., -0.07801617,
#          -0.07840686, -0.0030419 ]], shape=(5, 384)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.similarity_search(
    query="Who is a bowler?",
    k=5
)
# Out:
# [Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#  Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
    
)
# Out:
# [(Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.9693599939346313),
#  (Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.9693599939346313)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436007499694824),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436007499694824),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436007499694824),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.890937328338623)]

# %%
updated_doc1=Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team":"Royal Chllengers Banglore"}
)

vector_store.update_document(document_id='9a55bd5b-a6f2-479d-a7ec-610f0017f0e9',document=updated_doc1)

# %%
# view documents
vector_store.get(include=['documents'])
# Out:
# {'ids': ['5b540f85-3e13-44a5-8c59-1c9fe45cfbcf',
#   '209547b5-3a65-4d7b-9754-f26ffee9907c',
#   '57921b8e-bbb6-4420-9780-d51299cc00e2',
#   'cac9f275-6dba-4c60-b5f1-ff687d6ce92b',
#   'f6fa0844-6543-4570-be54-39b091c72eff',
#   'efa90347-7387-4bf4-85dd-cb8b2ef6a911',
#   '30aba286-e51d-48d4-9d98-cfe97e14ec62',
#   'b506bbf7-a8a7-4a30-94b9-9146b0942a95',
#   '0e5d8b42-c47f-4b75-9a60-7cd16480f13b',
#   'b44c2af2-78ad-48c3-9277-b72b34ddbd4c',
#   '9a55bd5b-a6f2-479d-a7ec-610f0017f0e9',
#   '61f56922-94ee-45c3-bbe9-ff23ac78ea4d',
#   'b5a97514-cfad-4c3d-943c-c5b5de646609',
#   '7021b11c-f14b-4021-885b-652242acfbc9',
#   'd790263b-ec9f-471d-928a-dfd18a0c491e'],
#  'embeddings': None,
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   "Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['documents'],
#  'data': None,
#  'metadatas': None}
