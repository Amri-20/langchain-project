# %%
from langgraph.graph import StateGraph,START,END
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
from typing import TypedDict,Annotated
from pydantic import BaseModel,Field
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate, PromptTemplate
import operator

# %%
load_dotenv()
# Out:
# True

# %%
llm=HuggingFaceEndpoint(
    repo_id="openai/gpt-oss-120b",
    task="text-generation"
)
model=ChatHuggingFace(llm=llm)

# %%
class EvaluationSchema(BaseModel):
    feedback:str=Field(
        description='Detailed feedback for the essay'
        )
    score:int=Field(
        description='Score out of 10',
        ge=0,
        le=10
    )

# %%
parser = JsonOutputParser(
    pydantic_object=EvaluationSchema
)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
template = PromptTemplate(
    template='''
You are an essay evaluator.

Return ONLY valid JSON.

{format_instructions}

Essay:
{essay}
''',
    input_variables=['essay'],
    partial_variables={
        'format_instructions': parser.get_format_instructions()
    }
)

# %%
prompt = template.format(
    essay=essay
)

result=model.invoke(prompt)

final_result=parser.parse(result.content)

# %%
result = model.invoke(prompt)

print(result.content)
# Out:
# {"feedback":"The essay provides a clear and well‑structured overview of India’s position in the emerging AI era. It opens with a strong hook, outlines key strengths such as the large STEM talent pool and vibrant IT sector, and then moves to specific application areas (agriculture, healthcare, education, governance). The discussion of challenges – digital divide, job displacement, data privacy – is relevant and balanced, and the concluding call for a multi‑stakeholder, ethical approach ties the argument together nicely.\\n\\nStrengths:\\n- Logical flow with distinct sections (strengths, opportunities, challenges, policy recommendations).\\n- Good use of concrete figures (e.g., 5 million STEM graduates) to support claims.\\n- Emphasis on inclusive growth and ethical considerations shows depth beyond a purely techno‑optimistic view.\\n\\nAreas for improvement:\\n- The essay would benefit from more up‑to‑date statistics or examples of successful AI pilots in India (e.g., specific agri‑tech platforms or health‑AI pilots).\\n- Some arguments are repetitive (the call for responsible AI appears several times); tighter editing could improve conciseness.\\n- Minor grammatical slips (e.g., missing articles, inconsistent tense) and occasional awkward phrasing could be polished with a final proofread.\\n- A brief comparison with other emerging AI economies would add context to the “

# %%
final_result
# Out:
# {'feedback': 'The essay provides a well‑structured overview of India’s position in the emerging AI era, clearly outlining both opportunities and challenges. It effectively highlights the country’s strengths—large talent pool, vibrant IT sector, and government initiatives—while offering concrete examples of AI applications in agriculture, healthcare, education, and governance. The discussion of risks such as the digital divide, job displacement, and data‑privacy concerns adds balance and demonstrates critical thinking. The call for multi‑stakeholder collaboration and international cooperation is appropriate and forward‑looking.\n\nHowever, the analysis could be deepened in several areas. The essay relies heavily on general statements and would benefit from specific statistics or case studies to substantiate claims (e.g., impact of AI‑driven agricultural tools on farmer yields). The treatment of policy recommendations is somewhat surface‑level; more concrete suggestions for skilling programs, regulatory frameworks, or data‑sharing mechanisms would strengthen the argument. Some sections repeat ideas (e.g., “AI as an enabler of human‑centered development”) without adding new insight. Additionally, the piece could improve coherence by linking the challenges more directly to the proposed solutions, and by providing a clearer roadmap for implementation.\n\nOverall, the essay is articulate, relevant, and demonstrates a good grasp of the topic, but would benefit from richer evidence and more detailed policy prescriptions to reach a higher level of scholarly rigor.',
#  'score': 8}

# %%
class UPSCState(TypedDict):
    essay:str
    language:str
    analysis:str
    clarity:str
    overall:str
    individual_scores:Annotated[list[int], operator.add]
    avg_score:float

# %%
def evaluate_analysis(state:UPSCState)->UPSCState:
    essay=state['essay']
    prompt=f'''You are an essay evaluator.
    Return ONLY valid JSON.
    The JSON format should be:
    {{
        "feedback":"your feedback here",
        "score":7
    }}
    Do not return markdown.
    Do not return explanation.
    Do not return table.
    Evaluate the language quality of the following essay and provide feedback and assign a score out of 10.
    Essay:
    {essay}'''
    output=model.invoke(prompt)
    result = parser.parse(output.content)
    return{
        'analysis':result['feedback'],
        'individual_scores':[result['score']]
    }

# %%
def evaluate_language(state:UPSCState)->UPSCState:
    essay=state['essay']
    prompt=f'''You are an essay evaluator.
    Return ONLY valid JSON.
    The JSON format should be:
    {{
        "feedback":"your feedback here",
        "score":7
    }}
    Do not return markdown.
    Do not return explanation.
    Do not return table.
    Evaluate the language quality of the following essay and provide feedback and assign a score out of 10.
    Essay:
    {essay}'''
    output=model.invoke(prompt)
    result = parser.parse(output.content)
    return{
        'language':result['feedback'],
        'individual_scores':[result['score']]
    }

# %%
def evaluate_thought(state:UPSCState)->UPSCState:
    essay=state['essay']
    prompt=f'''You are an essay evaluator.
    Return ONLY valid JSON.
    The JSON format should be:
    {{
        "feedback":"your feedback here",
        "score":7
    }}
    Do not return markdown.
    Do not return explanation.
    Do not return table.
    Evaluate the language quality of the following essay and provide feedback and assign a score out of 10.
    Essay:
    {essay}'''
    output=model.invoke(prompt)
    result = parser.parse(output.content)
    return{
        'clarity':result['feedback'],
        'individual_scores':[result['score']]
    }

# %%
# def final_evaluation(state:UPSCState)->UPSCState:
#     language=state['language']
#     analysis=state['analysis']
#     clarity=state['clarity']
#     prompt=f'Based on the following feedbacks create a summarized feedback \n language feedback - {language} \n depth of analysis feedback - {analysis} \n clarity of thought feedback - {clarity}'
#     overall_feedback = model.invoke(prompt)
#     result=parser.parse(overall_feedback.content)

#     avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

#     return{
#         'overall':overall_feedback.content,
#         'avg_score':avg_score
#     }

# %%
def final_evaluation(state:UPSCState)->UPSCState:

    language=state['language']
    analysis=state['analysis']
    clarity=state['clarity']

    prompt=f'''
    Based on the following feedbacks create a summarized feedback.

    Language Feedback:
    {language}

    Depth of Analysis Feedback:
    {analysis}

    Clarity of Thought Feedback:
    {clarity}
    '''

    overall_feedback=model.invoke(prompt)

    avg_score=sum(state['individual_scores'])/len(state['individual_scores'])

    return{
        'overall':overall_feedback.content,
        'avg_score':avg_score
    }

# %%
graph=StateGraph(UPSCState)


graph.add_node("Analysis",evaluate_analysis)
graph.add_node("Language",evaluate_language)
graph.add_node("Thought",evaluate_thought)
graph.add_node("Evaluation",final_evaluation)

graph.add_edge(START,"Analysis")
graph.add_edge(START,"Language")
graph.add_edge(START,"Thought")

graph.add_edge("Analysis","Evaluation")
graph.add_edge("Language","Evaluation")
graph.add_edge("Thought","Evaluation")

graph.add_edge("Evaluation",END)

workflow=graph.compile()

# %%
workflow

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
initial_state={'essay':essay}
workflow.invoke(initial_state)
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language': 'The essay is well‑structured and presents its ideas clearly, with effective paragraphing and logical flow. The vocabulary is appropriate and varied, and the writer demonstrates good command of complex sentence constructions. Minor issues include occasional wordiness, a few punctuation lapses (e.g., missing commas), and some redundant phrasing that could be tightened for greater impact. Overall, the language is fluent, coherent, and persuasive, reflecting a strong command of written English.',
#  'analysis': 'The essay demonstrates strong organization, clear thesis, and effective use of academic language. It presents a logical progression of ideas, integrates relevant examples, and employs a varied vocabulary appropriate for the topic. Minor issues include occasional redundancy, slightly wordy sentences, and a few awkward phrasing choices that could be tightened for greater impact. Strengthening sentence variety and eliminating repetitive language would enhance readability. Overall, the writing is coherent, well‑structured, and persuasive.',
#  'clarity': 'Your essay demonstrates strong command of English with clear organization, logical flow, and an appropriate academic tone. The introduction effectively sets the context, and each paragraph develops a distinct point with supporting details. Vocabulary is varied and largely precise, and sentences are generally well‑constructed. Minor issues include occasional repetition (e.g., “AI‑led growth” followed by “AI‑driven solutions”), a few awkward phrasing choices (“risk falling behind in the technology race”), and inconsistent hyphenation (“AI‑led” vs “AI‑driven”). A couple of commas could be placed more strategically for smoother reading. Overall, the language quality is high, with only small refinements needed to reach excellence.',
#  'overall': '**Summarized Feedback**\n\nYour essay is well‑structured, logically organized, and persuasive.\u202fYou consistently use an academic tone, varied vocabulary, and complex sentence constructions, which give the writing fluency and coherence.\u202fEach paragraph clearly advances the thesis with relevant examples and supporting details, and the introduction effectively sets the context.\n\n**What works well**\n- Clear overall organization and logical flow of ideas.  \n- Strong command of English; varied and appropriate word choice.  \n- Effective paragraphing and use of complex sentences.  \n- Persuasive argumentation supported by relevant examples.\n\n**Areas to tighten**\n- **Redundancy & wordiness:** occasional repeated phrases (e.g., “AI‑led growth” / “AI‑driven solutions”) and overly long sentences dilute impact.  \n- **Punctuation:** a few missing or misplaced commas; more strategic comma placement would improve readability.  \n- **Awkward phrasing & hyphenation:** occasional clumsy expressions (“risk fall behind in the technology race”) and inconsistent hyphenation (“AI‑led” vs. “AI‑driven”).  \n- **Sentence variety:** diversify structures a bit more to avoid monotony.\n\n**Overall impression**\n\nThe essay demonstrates high‑level language proficiency and clear thinking. With minor polishing—cutting redundant language, refining punctuation, and smoothing a few phrasing choices—you can elevate the work from strong to excellent.',
#  'individual_scores': [8, 8, 8],
#  'avg_score': 8.0}

# %%
initial_state={'essay':essay2}
workflow.invoke(initial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language': 'Your essay shows enthusiasm for AI in India, but the language is hindered by numerous grammatical, spelling, and punctuation errors. Sentence structure is often fragmented, and many words are misspelled (e.g., "Intel… something", "engine-ear", "doctor place"). The essay lacks clear organization; ideas jump without smooth transitions, and some points are vague. Consistent use of proper nouns, verb tenses, and articles would improve readability. Work on spelling, grammar, and paragraph cohesion to convey your ideas more effectively.',
#  'analysis': 'The essay conveys a clear overall message about AI’s potential and challenges in India, but the language is riddled with grammatical errors, misspellings, and awkward phrasing. Sentences often lack proper subject‑verb agreement, punctuation is inconsistent, and many words are misspelled (e.g., "Intel… something", "engine-ear", "farm" for "farmer", "doctor place"). The structure is repetitive and the ideas are not fully developed, making the text hard to follow. Improving sentence construction, spelling, and logical flow would greatly enhance readability.',
#  'clarity': 'The essay conveys a clear overall idea about AI in India but is plagued by numerous grammatical errors, misspellings, and awkward phrasing that hinder readability. Sentence structure is often fragmented, and the flow between points is weak, making the argument difficult to follow. Vocabulary is limited and many words are misspelled (e.g., "Intel…", "engine-ear", "doctor place"). The essay would benefit from better organization, clearer topic sentences, and proofreading for basic language conventions. Overall, the language quality is low.',
#  'overall': '**Summarized Feedback**\n\n**Strengths**\n- You demonstrate genuine enthusiasm for AI’s role in India and convey a clear overall message about its potential and challenges.\n\n**Main Areas for Improvement**\n1. **Language Mechanics**\n   - Frequent grammatical errors (subject‑verb agreement, verb tenses, article usage).\n   - Numerous misspellings (e.g., “Intel…”, “engine‑ear”, “doctor place”, “farm” for “farmer”).\n   - Inconsistent punctuation and fragmented sentence structures.\n\n2. **Organization & Cohesion**\n   - Ideas jump from one point to another without smooth transitions.\n   - Paragraphs lack clear topic sentences and logical progression, making the argument hard to follow.\n\n3. **Depth & Development of Ideas**\n   - Points are often vague or under‑developed; the essay feels repetitive.\n   - Limited vocabulary and awkward phrasing reduce the impact of your analysis.\n\n**Recommendations**\n- **Proofread** carefully for spelling, grammar, and punctuation; consider using a spell‑checker or grammar tool.\n- **Revise sentence structure** to create complete, varied sentences; avoid fragments.\n- **Organize the essay** with clear introductions, topic sentences, and concluding remarks for each paragraph; use transition words to link ideas.\n- **Expand and elaborate** on each point, providing specific examples or evidence to deepen the analysis.\n- **Enrich vocabulary** by reviewing synonyms and appropriate terminology for key concepts (e.g., “engineer,” “doctor’s office,” “farmer”).\n\nBy addressing these language and structural issues, your strong ideas about AI in India will be communicated much more effectively.',
#  'individual_scores': [3, 4, 3],
#  'avg_score': 3.3333333333333335}
